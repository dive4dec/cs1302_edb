# %% [markdown]
# ---
# title: Introduction to Computer Programming
# abstract: |
#    By the end of this material, readers will understand the intimate relationship between computers and programming, and appreciate the evolutions and motivations of programming languages. They will learn about basic computer architecture, binary data representation, and the structure of a Python program.
# skip_execution: true
# ---

# %% [markdown]
# ## Computer

# %% [markdown]
# ### What is a [computer](https://zh-yue.wikipedia.org/wiki/%E9%9B%BB%E8%85%A6)?

# %% [markdown]
# A calculator that is bigger and more advanced?

# %% [markdown]
# :::{figure} https://upload.wikimedia.org/wikipedia/commons/4/48/Calculator_app.png
# :name: fig:calculator-app
# :alt: Calculator app
# :align: left
#
# A calculator on a computer.
# :::

# %% [markdown]
# If so, is [abacus](https://en.wikipedia.org/wiki/Abacus) the first computer ever invented?

# %% [markdown]
# ::::{figure} https://upload.wikimedia.org/wikipedia/commons/a/af/Abacus_6.png
# :name: fig:abacus
# :alt: Abacus
# :align: left
#
# Abacus - an ancient mechanical computing device.
# ::::

# %% [markdown]
# Is your [smartphone](https://en.wikipedia.org/wiki/Samsung_DeX) a computer?

# %% [markdown]
# Run the following cell and click the play button to ask AI for some hints:[^run]
# [^run]: You can run a cell by selecting the cell and press <kbd>Shift + Enter</kbd>.

# %%
# %%hermes --no-context
# What defines a computer? Give me some hints but not the answer.

# %% [markdown]
# ::::{hint} Hints previously generated by the [`%%hermes --no-context` cell magic](https://github.com/dive4dec/jupyter-ai-hermes-magics). [^click]
# :class: dropdown
#
# Here are some hints:
#
# - Think about what makes a **calculator** different from a **computer**. A calculator does one fixed job — what extra capability does a computer have?
# - Imagine you tell someone a list of steps to follow. If you can **change the list** without changing the person, what property does that give them?
# - Consider: if you swap out one *thing* and suddenly your device can do something completely different, what did you swap?
#
# These point toward the core idea without spelling it out. Want me to add these as hints in the notebook cell?
#
# ::::
#
# [^click]: Click me to see the hints.

# %% [markdown]
# It might help to know...

# %% [markdown]
# :::::{important} Who invented the first computer?
# :class: dropdown
#
# ::::{card}
# :header: Who invented the first computer?
# :footer: [open in new tab](https://www.youtube.com/embed/d1pvc9Zh7Tg?si=99SDuN_zydUl_x4p)
#
# :::{iframe} https://www.youtube.com/embed/d1pvc9Zh7Tg?si=99SDuN_zydUl_x4p
# :width: 100%
# :::
#
# :::::

# %% [markdown]
# ### What is the architecture of a computer?

# %% [markdown]
# A computer contains three main hardware components:
#
# - Input device
# - Processing unit
# - Output device

# %% [markdown]
# #### Peripherals

# %% [markdown]
# ::::{figure} https://images.unsplash.com/flagged/photo-1551954810-43cd6aef5b1f?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=3580&q=80
# :name: fig:peripherals
# :alt: Peripherals
# :align: left
#
# Computer peripherals.
# ::::

# %% [markdown]
# Input and output devices connected to a computer are called *peripherals*.
# They allow users to interact with the computer in different ways.

# %% [markdown]
# ::::{exercise}
# :label: ex:output-device
#
# Some examples of output devices are:
# - Monitor
# - Speaker
#
# Can you give an awesome example in the following solution cell?[^edit]
# ::::
#
# [^edit]: To edit a markdown cell, double click the cell until you see a cursor. Run the cell to render the markdown code.

# %% [markdown]
# YOUR ANSWER HERE

# %%
# %%hermes --no-context
# Summarize what an output device of a computer is and explain briefly why
# a monitor and a speaker are examples?

# %% [markdown]
# An **output device** is a hardware component that converts processed data from the computer into a form perceivable by humans (or other systems).
#
# - A **monitor** displays visual data (text, images, video) — converting digital signals into light on a screen.
# - A **speaker** produces sound — converting digital audio signals into audible waves.
#
# Both take internal digital results and present them to the user, which is exactly what an output device does.

# %% [markdown]
# ::::{exercise}
# :label: ex:input-device
#
# Some examples of input devices are:
# - Keyboard
# - Mouse
#
# Can you give an awesome example?
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %%
# %%hermes --no-context
# Summarize what an input device of a computer is and explain briefly why
# a keyboard and a mouse are examples?

# %% [markdown]
# An **input device** is a hardware component that captures data or commands from the outside world (usually the user) and sends it into the computer for processing.
#
# - A **keyboard** translates key presses into digital signals representing characters and commands.
# - A **mouse** translates hand movements and clicks into digital signals controlling a cursor pointer.
#
# Both convert human actions into data the computer can process — which is exactly what an input device does.

# %%
# %%hermes --no-context
# Is headset an input device or an output device? Give me hints but not the answer.

# %% [markdown]
# Here are some hints:
#
# - A headset has **two distinct parts** — think about what each one does separately.
# - One part lets you **hear** audio from the computer. What category does that fit?
# - The other part captures your **voice**. What category does that fit?
#
# Think about it — does one label cover all of it, or could there be a third option?

# %% [markdown]
# ::::{exercise}
# :label: ex:input-output
#
# Can you give at least 3 additional examples that should be classified in the same way as a headset?
#
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# #### Central Processing Unit

# %% [markdown]
# ::::{figure}
# :name: fig:cpu
# :alt: CPU
# :align: left
#
# ![An Intel CPU](https://images.unsplash.com/photo-1555617981-dac3880eac6e?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1950&q=80)
#
# ![An AMD CPU](https://images.unsplash.com/photo-1591799265444-d66432b91588?q=80&w=1760&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D)
#
# Central processing units (CPUs) on motherboards.
# ::::

# %% [markdown]
# The brain of a computer is its processor or the [**C**entral **P**rocessing **U**nit (CPU)](https://en.wikipedia.org/wiki/Central_processing_unit). As shown in [](#fig:cpu), it is located on the [*motherboard*](https://en.wikipedia.org/wiki/Motherboard) and connected to different peripherals using different [*connectors*](https://en.wikipedia.org/wiki/Category:Computer_connectors).

# %% [markdown]
# For instance, you can check the CPU of your Jupyter Server by running the following shell command escaped using `!`:

# %%
# !lscpu

# %%
# %%hermes
# What does the above cell do?

# %% [markdown]
# The above cell runs the `!lscpu` shell command, which displays detailed information about the **CPU** (Central Processing Unit) of the Jupyter Server — including its architecture, number of cores, model name, clock speed, and cache sizes. The `!` prefix tells Jupyter to execute it as a terminal command rather than Python code.

# %% [markdown]
# ::::{tip}
#
# The information above is quite technical. Consider using AI to explain the terms to understand the CPU you are using for the Jupyter Server.
#
# ::::

# %% [markdown]
# Two important components in the CPU are:
# -  **A**rithmetic and **L**ogic **U**nit (**ALU**): Performs arithmetics like a calculator but for binary numbers. (More on this later.)
# -  **C**ontrol **U**nit (**CU**): Directs the operations of the processor in executing a program.

# %% [markdown]
# To visualize how CPU works, run the [CPU Simulator below](https://github.com/pddring/cpu-simulator).
# - Note that all values are zeros in the RAM (**R**andom **A**cess **M**emory) initially.
# - Under Settings, click `Examples`$\to $`Add two numbers`. Observe that the values in the RAM have changed.
# - Click `Run` at the bottom right-hand corner.

# %% [markdown]
# :::::{card}
# :footer: [Open in new tab](https://tools.withcode.uk/cpu)
#
# ::::{iframe} https://tools.withcode.uk/cpu
# :width: 100%
# ::::
#
# :::::

# %% [markdown]
# As you can see, in addition to performing arithmetic calculations,
# - a computer can be *programmed*
# - to perform different tasks.
#
# Can we simply say a computer is a programmable device? If so, what is programming?

# %% [markdown]
# ::::{seealso} A rigorous definition of a computer.
#
# Computer architecture may evolve over time, with new technologies and innovations emerging. However, modern computers follow the same mathematical principles of the [universal machine](https://doi.org/10.1112/plms/s2-42.1.230) defined by [Alan Turing, Father of Modern Computing](https://en.wikipedia.org/wiki/Alan_Turing). The definition is made to address the problem of computing, i.e., what numbers are computable by programming a machine. Do you have an easy way to understand [Turing's proof](https://en.wikipedia.org/wiki/Turing%27s_proof)?
#
# ::::

# %%
# %%hermes --no-context
# Explain very briefly how a universal machine look like.

# %% [markdown]
# Done. Added a new markdown cell explaining the universal machine — three components (tape, read/write head, rule set) and why it's "universal." It sits right after the `%%hermes --no-context` question cell.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# A **universal machine** (Turing machine) has three simple parts:
#
# 1. An infinitely long **tape** divided into cells, each holding a symbol
#    (e.g., 0 or 1).
# 2. A **read/write head** that scans one cell at a time, reading the symbol
#    and optionally overwriting it.
# 3. A **finite set of rules** (the program) that tells the machine: given the
#    current symbol and internal state, what to write, which way to move (left
#    or right), and what state to enter next.
#
# Despite this simplicity, by changing the rules (the program) on the tape,
# the same machine can compute *any* computable function — which is why it is
# called "universal".
# ::::

# %%
# %%hermes --no-context
# How the problem of decidability has to do with definability and computability?

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# The three concepts are tightly intertwined:
#
# - **Definability** asks whether a mathematical object (e.g., a set of
#   numbers) can be precisely described using a formal language.
# - **Computability** asks whether there exists an algorithm — a mechanical
#   procedure a machine can follow — to produce or decide that object.
# - **Decidability** asks whether, for any given input, there is an algorithm
#   that always halts with a correct yes/no answer.
#
# Turing showed that not every *definable* set is *computable*, and not every
# computable problem is *decidable*. His proof that the Halting Problem is
# undecidable means there are well-defined questions for which no algorithm
# can ever give a definitive answer — establishing a fundamental limit on
# what computers can do.
# ::::

# %% [markdown]
# ## Programming

# %% [markdown]
# ### What is programming?

# %% [markdown]
# ::::{important} What defines programming?
# :class: dropdown
#
# *Programming*, also called *software development*, is the process of writing programs for the computer to execute different tasks. But what is a program?
# ::::

# %% [markdown]
# ::::{exercise}
# :label: ex:machine-language
#
# You have just seen a program written in [machine language](https://en.wikipedia.org/wiki/Machine_code). Where?
#
# :::{hint}
# :class: dropdown
#
# It is stored somewhere in RAM (**R**andom **A**cess **M**emory), which is used to store data and programs.[^architecture]
#
# :::
#
# ::::
#
# [^architecture]: The CPU simulator follows the [von Neumann architecture](https://doi.org/10.1109/85.238389), which realizes Turing's conception of the [*stored-program computer*](https://en.wikipedia.org/wiki/Stored-program_computer), where program and data are stored in the same memory. This is in contrast to the Harvard architecture, which uses separate memories for program and data.

# %% [markdown]
# YOUR ANSWER HERE

# %%
# %%hermes --no-context
# As a hint, summarize what a machine language is and give an example of a program
# in machine language.

# %% [markdown]
# Done. Added the machine language hint as a markdown cell right after the `%%hermes --no-context` question, explaining binary opcodes with a concrete example that ties back to the CPU simulator's RAM.

# %% [markdown]
# ::::{hint}
# :class: dropdown
#
# **Machine language** is the lowest-level programming language: a sequence of
# binary codes that the CPU can execute directly, with no translation needed.
# Each binary pattern (opcode) represents one instruction, such as `Add`,
# `Store`, `Jump`, or `End`.
#
# For example, the CPU simulator's "Add two numbers" program might look like:
#
# ```
# 0000000000000001   ; Load value at address 1 into register A
# 0001000000000010   ; Add value at address 2 to register A
# 0010000000000011   ; Store register A into address 3
# 0011000000000000   ; End program
# ```
#
# Every line is a binary number — the CPU reads each one as an instruction
# and its operand. This is what is stored in the RAM of the simulator.
#
# ::::

# %% [markdown]
# The CPU is capable of carrying out
# - a set of instructions such as `Add`, `Subtract`, `Store`, etc.,
# - for some numbers stored in the RAM.

# %% [markdown]
# Both the instructions and the numbers are represented as binary sequences.

# %% [markdown]
# ### Why computer uses binary representation?

# %% [markdown]
# :::{figure} https://upload.wikimedia.org/wikipedia/commons/8/8c/Two_women_operating_ENIAC_%28full_resolution%29.jpg
# :name: fig:ENIAC
# :alt: Two programmers operating ENIAC.
# :align: left
#
# Programmers controlling the switches of ENIAC.
# :::

# %% [markdown]
# ::::::{exercise}
# :label: ex:ENIAC
#
# [](#fig:ENIAC) is a photograph of the first electronic computer, called [Electronic Numerical Integrator and Computer (ENIAC)](https://en.wikipedia.org/wiki/ENIAC). It was programmed using binary circuitries, namely *switches* that can be either `On` or `Off`. However, it did not represent numbers efficiently in binary. 10 switches (bits) were used to represent a digit: Each switch indicates a possible value from 0 to 9. Indeed, how many decimal number can be represented by 10 bits?
#
# :::::{hint}
# :class: dropdown
#
# ::::{card}
# :header: Binary representation
# :footer: [open in new tab](https://youtu.be/Xpk67YzOn5w)
#
# :::{iframe} https://www.youtube.com/embed/Xpk67YzOn5w
# :width: 100%
# :::
#
# ::::
# :::::
#
# ::::::

# %%
# YOUR CODE HERE
raise NotImplementedError

# %%
# %%hermes --no-context
# As a hint, explain the multiplication rule in combinatorics.

# %% [markdown]
# ::::{hint}
# :class: dropdown
#
# The **multiplication rule** (or rule of product) says: if you have a sequence
# of independent choices, the total number of outcomes is the *product* of the
# number of options at each step.
#
# For example, if there are 10 switches and each can be either `On` or `Off`
# (2 choices), the total number of distinct configurations is
# $$2 \times 2 \times \dots \times 2 = 2^{10} = ?$$
#
# The solution cell to the above exercise is a code cell, so why not use the
# exponentiation operator `**` to calculate the value?
#
# ::::

# %% [markdown]
# ::::{seealso} Why use binary numbers?
# :class: dropdown
#
# Unlike ENIAC, the subsequent design of the Electronic Discrete Variable Computer (EDVAC) utilized the binary number system. The decision was explained in Section 5.1 of the [design report](https://doi.org/10.1109/85.238389) authored by [John von Neumann](https://en.wikipedia.org/wiki/John_von_Neumann) in 1945. While humans are accustomed to using the decimal number system, von Neumann justified the use of binary by noting that human neurons operate in a binary manner:
#
# > The analogs of human neurons ... are equally all-or-none elements. It will appear that they are quite useful for all preliminary, orienting, considerations of vacuum tube systems ... It is therefore satisfactory that here too the natural arithmetical system to handle is the binary one.
# > — John von Neumann
#
# ::::

# %% [markdown]
# There are *International Standards* for representing characters:
# - [ASCII](https://en.wikipedia.org/wiki/ASCII) (**A**merican **S**tandard **C**ode for **I**nformation **I**nterchange) maps English letters and some other symbols to 8-bits (8 binary digits, also called a byte). E.g., `A` maps to `01000001`.
# - [Unicode](https://en.wikipedia.org/wiki/Unicode) can also represent characters in different languages such as Chinese, Japanese...etc.

# %% [markdown]
# There are also additional standards to represent numbers other than non-negative integers:
# - [2's complement format](https://en.wikipedia.org/wiki/Two%27s_complement) for negative integers (e.g. -123)
# - [IEEE floating point format](https://en.wikipedia.org/wiki/IEEE_754) for floating point numbers such as $1.23 \times 10^{-4}$.

# %%
# %%hermes
# In addition to the ones in the above cell, what are other standards for
# representing characters/numbers in computers.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
# Beyond ASCII, Unicode, 2's complement, and IEEE 754 floating point:
#
# **Characters:**
# - **EBCDIC** — IBM's legacy encoding for mainframes (8-bit, different mapping than ASCII).
# - **UTF-8 / UTF-16 / UTF-32** — Specific Unicode encoding schemes (variable-width vs. fixed-width trade-offs).
# - **ISO-8859-x (Latin-x)** — Extended 8-bit character sets for European languages that bridge ASCII and full Unicode.
#
# **Numbers:**
# - **BCD (Binary-Coded Decimal)** — Each decimal digit is stored as a separate 4-bit binary nibble; used in financial systems to avoid floating-point rounding errors.
# - **Fixed-point representation** — Scales fractional values by a constant factor (e.g., Q16 format), common in embedded DSP and audio processing.
# - **Decimal128 (IEEE 754-2008)** — A 128-bit decimal floating-point format for precise financial calculations.
#
# ::::

# %% [markdown]
# ::::{important} Why define different standards for representing characters/numbers?
# :class: dropdown
#
# Different standards have different benefits.
# - ASCII requires less storage for a character, but it represents less characters.
# - Although digits are also represented in ASCII, the 2's complement format is designed for more efficient arithmetic operations.
#
# ::::

# %% [markdown]
# ## Generations of programming languages

# %% [markdown]
# ::::{important}
#
# A *machine language* written in *binary sequences* is known as a *1st Generation Programming Language*.
# ::::

# %% [markdown]
# **Are we going to start with machine language?**
# Start with learning 2's complement and the binary codes for different instructions?

# %% [markdown]
# No. Programmers do not write machine codes directly because it is too hard to think in binary representations.

# %% [markdown]
# Instead, programmers write human-readable **mnemonics** such as `ADD`, `SUB`, ...
# This is called the *assembly language*. An example is shown in [](#fig:assembly-language).

# %% [markdown]
# ::::{figure} https://upload.wikimedia.org/wikipedia/commons/f/f3/Motorola_6800_Assembly_Language.png
# :name: fig:assembly-language
# :alt: Assembly language
# :align: left
#
# A Code written in an assembly language.
# ::::

# %% [markdown]
# ::::{important}
#
# An *assembly language* written in *mnemonics* is the *2nd Generation Programming Language*.
# ::::

# %%
# %%hermes --no-context
# What is the assembly language most commonly used by programmers and what is its
# main application?

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# There isn't a single "most common" assembly language — each CPU architecture has its own. The two most widespread today:
#
# - **x86/x86-64 assembly** — Dominates desktops and servers (Intel/AMD). Used for OS kernels, device drivers, and performance-critical code like game engines or cryptography.
# - **ARM assembly** — Dominates mobile devices and embedded systems (smartphones, IoT). Also used in Apple Silicon Macs. Used for low-level hardware control, bootloaders, and power-efficient optimized code.
#
# **Main application:** Assembly is rarely written from scratch by programmers today. Its primary use is in **low-level system programming** — operating systems drivers, firmware/BIOS, performance-critical optimization where every cycle matters, and reverse engineering/security research. Most programmers rely on compilers that translate high-level languages down to the appropriate assembly automatically.
#
# ::::

# %%
# %%hermes --no-context
# Explain the different instructions used in the different instruction set
# architectures including AMD, ARM, and RISC-V.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# These three architectures differ fundamentally in their design philosophy:
#
# **AMD x86/x86-64 (CISC — Complex Instruction Set Computer)**
# - Variable-length instructions (1 to 15 bytes)
# - Instructions can perform multi-step operations in one step, e.g., `ADD [mem], reg` reads memory, adds, and writes back simultaneously.
# - Rich addressing modes allow complex memory access patterns directly inside an instruction.
# - Example instructions: `MOV`, `ADD`, `PUSH`, `CALL`, `CMOVcc` (conditional move), plus SIMD extensions like `SSE`/`AVX` for parallel math on vectors.
#
# **ARM (RISC — Reduced Instruction Set Computer)**
# - Fixed-length instructions (32-bit in ARMv7/ARMv8)
# - Strict load/store architecture: arithmetic only operates on registers; memory access requires explicit `LDR`/`STR` instructions.
# - Fewer, simpler instructions that execute in a single cycle.
# - Example instructions: `ADD`, `SUB`, `LDR`, `STR`, `B` (branch), `BL` (branch with link/call). Registers are named `X0–X30` (AArch64), plus dedicated stack pointer (`SP`) and program counter (`PC`).
#
# **RISC-V (Open-source RISC)**
# - Fixed 32-bit base instructions with optional extensions (`M` for multiply, `A` for atomics, `F/D` for floating point).
# - Same load/store philosophy as ARM, with uniform register names: general-purpose registers are simply numbered `x0–x31`. Notable convention: register zero is hardwired to always return 0.
# - Modular and extensible by design — you pick only the features your hardware needs.
# - Example instructions: `add`, `sub`, `lw`/`sw` (load/store word), `beq`/`bne` (branch if equal/not equal), jal/jalr (jump-and-link).
#
# **Summary:** CISC packs more work into fewer but complex instructions; RISC breaks everything into simple steps that run fast and compile cleanly.
#
# ::::

# %% [markdown]
# **Are you going to learn an assembly language?**

# %% [markdown]
# Both machine language and assembly language are low-level languages which are
# - difficult to write for complicated tasks (requiring many lines of code), and
# - platform-specific, i.e.,
#     - the sets of instructions and their binary codes can be different for different [types of CPUs](https://en.wikipedia.org/wiki/Comparison_of_CPU_microarchitectures), and
#     - different operating systems use [different assembly languages/styles](https://en.wikipedia.org/wiki/X86_assembly_language).

# %% [markdown]
# ::::{note} Who needs to learn assembly languages?
# :class: dropdown
#
# Probably for programmers who need to write fast or energy-efficient code such as
# - a driver that controls a 3D graphics card, or
# - a program that control a microprocessor with limited power supply.
#
# But even in the above cases, there are often better alternatives. Play with the following microprocessor simulator:
#
# - Open <https://micropython.org/unicorn/> in a browser.
# - Click `CHOOSE A DEMO`$\to $`LED`.
# - Click `RUN SCRIPT` and observes the LED of the board.
# - Run the demos `ASSEMBLY` and `MATH` respectively and compare their capabilities.
#
# ::::

# %% [markdown]
# ## High-level Language

# %% [markdown]
# **What is a high-level language?**

# %% [markdown]
# :::::{card}
# :header: The art of programming
# :footer: [open in new tab](https://youtu.be/QdVFvsCWXrA)
#
# ::::{iframe} https://www.youtube.com/embed/QdVFvsCWXrA
# :width: 100%
# ::::
#
# :::::

# %% [markdown]
# Programmers often write in human-readable languages such as
#
# - Python
# - Rust
# - C/C++
# - Java
# - JavaScript
# - Typescript
# - Pascal
# - Basic
# - HTML
# - PHP
# - ...
#
# called *high-level languages*.

# %% [markdown]
# ::::{important}
#
# A *high-level language* intended to be *human understandable* is a *3rd Generation Programming Language*.
#
# ::::

# %% [markdown]
# - A program written in a high-level language gets converted automatically to a low-level machine code for the desired platform.
# - This *abstracts* away low-level details that can be handled by the computer automatically.

# %% [markdown]
# For instance, a programmer needs not care about where a value should be physically stored if the computer can find a free location automatically to store the value.

# %% [markdown]
# Different high-level languages can have different implementations of the conversion processes:
# - **Compilation** means converting a program well before executing the program.
#   E.g., C++ and Java programs are compiled.
# - **Interpretation** means converting a program on-the-fly during the execution of a program.
#   E.g., JavaScript and Python programs are often interpreted.

# %% [markdown]
# ::::{seealso} Compiled vs interpreted languages
# :class: dropdown
#
# Roughly speaking, compiled programs run faster but interpreted programs are more flexible and can be modified at run time. The [truth](https://finematics.com/compiled-vs-interpreted-programming-languages/) is indeed more complicated. Python also has a compiler, and recently, a [JIT compiler](https://github.com/python/cpython/pull/113465). Is Python really an interpreted language?
#
# ::::

# %%
# %%hermes --no-context
# Explain in one or two paragraphs whether Python is really an interpreted
# language, given that it also has a compiler and, recently, a JIT compiler, and
# it can be run as a script like a scripting language.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# Python **compiles** source code into an intermediate form called *bytecode*, which is
# then **interpreted** by the CPython virtual machine. So it is both compiled and
# interpreted — the compilation happens automatically behind the scenes, and users
# never see the bytecode. The recent experimental [JIT
# compiler](https://github.com/python/cpython/pull/113465) takes another step by
# compiling hot bytecode paths into native machine code at runtime, similar to how
# Java or JavaScript engines work. Despite all this, calling Python an "interpreted"
# language remains useful shorthand: from the programmer's perspective, there is no
# explicit compile step — you just run the script directly, making it feel like a
# scripting language.
# :::::

# %% [markdown]
# You will learn to program in [*Python*](https://youtu.be/J0Aq44Pze-w?si=NLwclo8jaqUla1bx), which is a popular language. (See [*TIOBE (The Importance of Being Efficient) Programming Community Index*](https://www.tiobe.com/tiobe-index/)).

# %%
# %%hermes --no-context
# What is the popularity of Python according to the TIOBE?

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# Python has held the **#1 position** on the TIOBE index since October 2021, making it
# the most popular programming language according to that index. It currently
# maintains a healthy lead over its nearest competitors (typically C, C++, and
# Java), with its popularity driven by its widespread use in data science, machine
# learning, web development, and education.
#
# ::::

# %% [markdown]
# :::::{note} Why Python?
# :class: dropdown
#
# Python is:
# - *expressive* and can get things done with fewer lines of code as compared to other languages.
# - *popular*. It has an extensive set of libraries for Mathematics, graphics, AI, Machine Learning, etc.
# - *free and open-source*, so you get to see everything and use it without restrictions.
# - *portable*, i.e., the same code runs in different platforms without modifications.
#
# ::::{card}
# :footer: [open in new tab](https://youtu.be/Y8Tko2YC5hA)
#
# :::{iframe} https://www.youtube.com/embed/Y8Tko2YC5hA?end=200
# :width: 100%
# :::
#
# ::::
#
# :::::

# %% [markdown]
# **How does a Python program look like?**

# %%
import datetime  # library to obtain current time

cohort = input("In which year did you join CityU? [e.g., 2020]")
year = (
    datetime.datetime.now().year # current year
    - int(cohort)
    + (1 if datetime.datetime.now().month >= 9 else 0) # Why use current month?
)
print("So you are a year", year, "student.")

# %% [markdown]
# A Python program contains *statements* just like sentences in natural languages. E.g.,
# ```python
# cohort = input("In which year did you join CityU? ")
# ```
# which obtains some information from user input.

# %% [markdown]
# For the purpose of computations, a statement often contains *expressions* that evaluate to certain values.  E.g.,
# ```python
# input("In which year did you join CityU? ")
# ```
# is an expression with the value equal to what you input to the prompt.
# That value is then given the name `cohort`.

# %% [markdown]
# Expressions can be composed of the following objects:
# - *Functions* such as `input`, `now`, and `int`, etc., which are like math functions the return some values based on its arguments, if any.
# - *Literals* such as the string `"In which year did you join CityU? "` and the integer `1`. They are values you type out literally.
# - *Variables* such as `cohort` and `year`, which are meaningful names to values.

# %% [markdown]
# To help others understand the code, there are also *comments* that start with `#`.
# These are meant to explain the code to human but not to be executed by the computer.

# %% [markdown]
# ::::{exercise}
# :label: ex:future-programming
#
# What do you think the next generation programming should be?
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %%
# %%hermes --no-context
# What do you think the next generation programming should be?

# %% [markdown]
# ## Agentic Coding

# %% [markdown]
# ### What is agentic coding?

# %% [markdown]
# In traditional programming (3rd generation), you write **step-by-step instructions** for the computer to follow. The computer executes them literally but has no understanding of your *goal*.
#
# In **agentic coding**, you specify a **goal** — "build a webpage that shows weather data" — and an AI agent plans, writes code, runs it, debugs errors, and iterates until the goal is met. You shift from *writing every line* to *specifying outcomes and supervising the process*.

# %% [markdown]
# :::{table} Comparing programming paradigms
# :name: tbl:programming-generations
#
# | Generation | Paradigm | You say... | Computer does... |
# |:-----------|:---------|:-----------|:-----------------|
# | 1st | Machine language | `01000001` (binary) | Executes the exact binary operation |
# | 2nd | Assembly | `ADD R1, R2` | Adds two registers |
# | 3rd | High-level (Python) | `for i in range(10): print(i)` | Loops and prints — follows your steps |
# | **4th?** | **Agentic** | **"Create a graph showing prime number distribution"** | **Plans, codes, runs, debugs, delivers** |
#
# :::

# %% [markdown]
# ### How does an agent work?

# %% [markdown]
# An agentic coder follows a **plan-execute-reflect** loop:
#
# 1. **Plan** — Break the goal into sub-tasks
# 2. **Write** — Generate code for each sub-task
# 3. **Execute** — Run the code and observe output or errors
# 4. **Reflect** — If errors or incomplete results, revise and repeat

# %% [markdown]
# The key difference from just asking AI to "write code" is the **iteration loop**: the agent runs its own code, reads error messages, and fixes problems autonomously. You act as the *product manager*, not the *line-by-line implementer*.

# %% [markdown]
# ### Try it yourself

# %% [markdown]
# Run the cell below. Describe a small programming task in natural language and observe how the AI agent responds:

# %%
# %%ai
# Task: Write a Python function that takes a list of words and returns a
# dictionary counting the frequency of each word, case-insensitive.
# Then test it with ["Hello", "World", "hello", "WORLD", "Python", "PYTHON"].

# %% [markdown]
# ::::{tip}
#
# Compare this to how you would write it in Python yourself. Which approach felt faster? Which gave you more control? In practice, agentic coding excels for **prototyping and exploration**, while traditional coding remains essential for **debugging complex logic and understanding what's happening under the hood**.
#
# ::::

# %% [markdown]
# ::::{exercise}
# :label: ex:agentic-vs-traditional
#
# Think of a programming task you'd give to an agentic coder and one you'd prefer to write yourself in Python. Explain your reasoning for each choice.
#
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{important}
#
# Agentic coding is not a replacement for learning to program — it **assumes** you can read, review, and reason about code. The best programmers of the future will be those who can both **write code themselves** and **effectively direct an AI agent**.
#
# ::::
